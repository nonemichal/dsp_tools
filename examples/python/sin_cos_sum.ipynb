# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
from ipywidgets import interactive

# %%
def plot_mixed(A1, A2):
    x = np.linspace(0, 1, 100)
    f = 2
    phi = 0 * np.pi

    sinus = A1 * np.sin(2 * np.pi * f * x + phi)
    cosinus = A2 * np.cos(2 * np.pi * f * x + phi)
    mixed = sinus + cosinus

    plt.plot(x, sinus, label="sinus", linestyle="--")
    plt.plot(x, cosinus, label="cosinus", linestyle="--")
    plt.plot(x, mixed, label="mixed", linewidth=2)

    plt.ylim(-8, 8)
    plt.xlim(0, 1)
    plt.legend(loc="lower left")
    plt.grid(True)

    plt.show()

# %%
interactive_mixed = interactive(plot_mixed, A1=(0, 5, 0.1), A2=(0, 5, 0.1))
output = interactive_mixed.children[-1]
output.layout.height = '450px'
interactive_mixed
# Out:
# interactive(children=(FloatSlider(value=2.0, description='A1', max=5.0), FloatSlider(value=2.0, description='A…
